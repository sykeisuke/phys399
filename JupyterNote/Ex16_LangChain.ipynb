# %% [markdown]
# # Exercise 16: LangChain and Retrieval-Augmented Generation (RAG)
#
# **Goals**
# - Learn how to build a **vector database** using LangChain and Chroma.
# - Create a simple **Retrieval-Augmented Generation (RAG) chatbot** that can answer customer inquiries using product data.
# - Compare semantic search with exact price and stock filters.
# - Understand how AI can be applied to **industrial use cases** such as online retail and customer support.
#
# Run this notebook from the `JupyterNote` folder so `data/data_ex16.csv` is found. Install/update packages with `%pip install -U langchain langchain-openai langchain-chroma` if needed. API calls for embeddings and chat may incur charges. Never paste your API key into a saved notebook.

# %%
import os
from getpass import getpass
import pandas as pd
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain.tools import tool
from langchain.agents import create_agent

if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("OpenAI API key: ")

# %%
CSV_PATH = "data/data_ex16.csv"
EMB_MODEL = "text-embedding-3-small"
CHAT_MODEL = "gpt-6-luna"

# %%
# ----------------- Check CSV -----------------
df = pd.read_csv(CSV_PATH)
print(df.head())
print(df.dtypes)

# %%
# ----------------- Load CSV -> Documents -----------------
def csv_to_documents(csv_path):
    df = pd.read_csv(csv_path)
    docs = []
    
    for i in range(len(df)):
        row = df.iloc[i]
        content = (
            "Product: " + str(row["name"]) + "\n"
            "Category: " + str(row["category"]) + "\n"
            "Price (USD): " + str(row["price_usd"]) + "\n"
            "Stock: " + str(row["stock"]) + "\n"
            "Description: " + str(row["description"])
        )
        docs.append(Document(page_content=content, metadata={"product_id": int(row["id"])}))

    return docs

# %%
# ----------------- Build an in-memory Chroma database -----------------
def build_chroma(docs):
    embeddings = OpenAIEmbeddings(model=EMB_MODEL)
    vectordb = Chroma(collection_name="phys399_shoes", embedding_function=embeddings)
    # Stable IDs prevent duplicate entries if this cell is rerun.
    ids = [str(doc.metadata["product_id"]) for doc in docs]
    vectordb.add_documents(documents=docs, ids=ids)
    return vectordb

# %%
# ----------------- Give the agent two complementary tools -----------------
def build_tools(vectordb, catalog_df):
    @tool
    def search_shoes(query: str) -> str:
        """Search the shoe catalog by product name, category, or description."""
        matches = vectordb.similarity_search(query, k=4)
        if not matches:
            return "No matching products found."
        return "\n\n".join(doc.page_content for doc in matches)

    @tool
    def filter_shoes(category: str = "", max_price_usd: float = 0.0, in_stock_only: bool = False) -> str:
        """Filter the CSV catalog exactly by category, maximum price, and stock. Use 0 for no price limit."""
        matches = catalog_df
        if category:
            matches = matches[matches["category"].str.lower() == category.lower()]
        if max_price_usd > 0:
            matches = matches[matches["price_usd"] <= max_price_usd]
        if in_stock_only:
            matches = matches[matches["stock"] > 0]
        if matches.empty:
            return "No products match those exact filters."
        return "\n".join(
            f"{row['name']} | {row['category']} | ${row['price_usd']:.2f} | stock: {row['stock']}"
            for _, row in matches.iterrows()
        )

    return [search_shoes, filter_shoes]

# %%
# ----------------- Minimal RAG agent -----------------
def build_agent(tools):
    llm = ChatOpenAI(model=CHAT_MODEL, use_responses_api=True, reasoning_effort="none")
    return create_agent(
        model=llm,
        tools=tools,
        system_prompt=(
            "You are a helpful assistant for a shoes-only online shop. "
            "Use search_shoes for descriptive questions and filter_shoes for exact price, category, or stock constraints. "
            "Answer only from the tool results. "
            "Include names and prices when relevant; if the results do not support an answer, say you don't know. "
            "Do not invent sizes, colors, or stock information."
        ),
    )

# %%
# ----------------- Main -----------------
def main():
    # 1) Read CSV -> Documents
    docs = csv_to_documents(CSV_PATH)

    # 2) Build an in-memory Chroma vector DB
    vectordb = build_chroma(docs)

    # 3) Build RAG agent (LLM + semantic and exact-filter tools)
    tools = build_tools(vectordb, pd.read_csv(CSV_PATH))
    agent = build_agent(tools)

    # 4) Run the agent
    user_q = "I'm looking for running shoes for daily training. What options and prices do you have?"
    res = agent.invoke({"messages": [{"role": "user", "content": user_q}]})

    print("\n--- Agent answer ---")
    print(res["messages"][-1].text)

if __name__ == "__main__":
    main()
